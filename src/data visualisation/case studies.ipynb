# %% [markdown]
# # Load Helper Functions

# %%
from util import get_service_area, load_Baltimore_blocks
import geopandas as gpd
import pickle
import datetime
import folium
from r5py import TransportNetwork, DetailedItinerariesComputer, TransportMode
import warnings
warnings.filterwarnings('ignore')

gdf_Baltimore, md_rac_df, md_wac_df = load_Baltimore_blocks()
stations = gpd.read_file(f'../../raw_data/Baltimore Red Line- Stations.csv')
segments = gpd.read_file(f'../../raw_data/Baltimore Red Line- Alignment.csv')
service_area = get_service_area(gdf_Baltimore, stations)
residents = service_area.merge(md_rac_df, left_on='GEOID20', right_on='h_geocode')
#pickle.dump(residents, open('../../processed_data/residents.pkl', 'wb'))
workplace = pickle.load(open('../../processed_data/workplace.pkl', 'rb'))
osm_fp = '../../raw_data/maryland-latest.osm.pbf'
GTFS = ['../../processed_data/updated_gtfs/2023-04-10.zip', '../../raw_data/commuterbus_gtfs.zip', '../../raw_data/subway_gtfs.zip',
                  '../../raw_data/train_gtfs.zip', '../../raw_data/rail_gtfs.zip']

transport_network_before_newline = TransportNetwork(
        osm_fp,
        GTFS
    )

GTFS = ['../../processed_data/updated_gtfs/2023-04-10.zip', '../../raw_data/commuterbus_gtfs.zip', '../../raw_data/subway_gtfs.zip',
                  '../../raw_data/train_gtfs.zip', '../../raw_data/rail_gtfs.zip', '../../processed_data/redline.zip']

transport_network_after_newline = TransportNetwork(
        osm_fp,
        GTFS
    )

# %%
def compute_itineraries(transport_network, origin, destination, center = [39.2900, -76.6480]):

    origins = residents[residents['GEOID20'] == origin]
    origins['id'] = origins['GEOID20']
    origins = origins[['geometry', 'id']]

    destinations = workplace[workplace['GEOID20'] == destination]
    destinations['id'] = destinations['GEOID20']
    destinations = destinations[['geometry', 'id']]
    
    origins.geometry = origins.geometry.centroid
    destinations.geometry = destinations.geometry.centroid

    detailed_itineraries_computer = DetailedItinerariesComputer(
            transport_network,
            origins=origins,
            destinations=destinations,
            departure=datetime.datetime(2023, 4, 10, 8, 0),
            transport_modes=[TransportMode.TRANSIT, TransportMode.WALK],
            departure_time_window = datetime.timedelta(minutes=10)
        )

    travel_details = detailed_itineraries_computer.compute_travel_details()

    travel_details["mode"] = travel_details.transport_mode.astype(str)
    travel_details["travel time (min)"] = travel_details.travel_time.apply(
        lambda t: round(t.total_seconds() / 60.0, 2)
    )

    travel_details["wait time (min)"] = travel_details.wait_time.apply(
        lambda t: round(t.total_seconds() / 60.0, 2)
    )


    options = travel_details.groupby("option")["travel time (min)"].sum() + travel_details.groupby("option")["wait time (min)"].sum()

    travel_details = travel_details[travel_details['option'] == options.idxmin()]

    city_map = folium.Map(location=center, zoom_start=13)

    color_dict = {
        'TransportMode.BUS': 'blue',
        'TransportMode.SUBWAY': 'gray',
        'TransportMode.TRAM': 'red',
        'TransportMode.WALK': 'green',
    }


    for _, station in origins.iterrows():
        folium.Marker(
            location=[station.geometry.y, station.geometry.x],  # Extract latitude and longitude from the geometry
            icon=folium.Icon(color='red'),  # Specify the custom icon,
        ).add_to(city_map)


    for _, station in destinations.iterrows():
        folium.Marker(
            location=[station.geometry.y, station.geometry.x],  # Extract latitude and longitude from the geometry
            icon=folium.Icon(color='green'),  # Specify the custom icon,
        ).add_to(city_map)

    for _, route in travel_details.iterrows():
        folium.PolyLine(
            locations=[(lat, lon) for lon, lat in route['geometry'].coords],
            color=color_dict[route['mode']],
            weight=3,
            opacity=1,
            dash_array='5, 5',
            tooltip=route['mode']
        ).add_to(city_map)

    colors = [color_dict[mode] for mode in travel_details['mode'].unique()]
    labels = [mode for mode in travel_details['mode'].unique()]
    legend_html = '<div style="background: white; width: 200px; height: 70px; border: 1px solid black;font-size: 16px;">'
    for i in range(len(colors)):
        legend_html += f"""
        <div><span style="background-color: {colors[i]}; 
                        width: 10px; 
                        height: 10px; 
                        display: inline-block; 
                        margin-left: 5px; margin-right: 5px;"></span >{labels[i]}</div>"""
    legend_html += '</div>'

    legend_icon = folium.DivIcon(html=legend_html)
    return options, travel_details, city_map

# %% [markdown]
# # Aisha
# Aisha travels from block 245101607002002 to 245100402001036

# %%
options, travel_details, city_map = compute_itineraries(transport_network_before_newline, '245101607002002', '245100402001036')
print(options.min())
travel_details
# Out:
# 45.58
#             from_id            to_id  option  segment      transport_mode  \
# 16  245101607002002  245100402001036       4        0  TransportMode.WALK
# 17  245101607002002  245100402001036       4        1   TransportMode.BUS
# 18  245101607002002  245100402001036       4        2  TransportMode.WALK
# 19  245101607002002  245100402001036       4        3   TransportMode.BUS
# 20  245101607002002  245100402001036       4        4  TransportMode.WALK
#
#         departure_time  distance     travel_time       wait_time  \
# 16 2023-04-10 08:06:15   156.667 0 days 00:02:34 0 days 00:00:00
# 17 2023-04-10 08:12:41       NaN 0 days 00:07:53 0 days 00:01:01
# 18 2023-04-10 08:21:34    90.732 0 days 00:01:30 0 days 00:01:08
# 19 2023-04-10 08:27:50       NaN 0 days 00:12:20 0 days 00:05:38
# 20 2023-04-10 08:41:10   801.863 0 days 00:13:31 0 days 00:00:00
#
#               route                                           geometry  \
# 16             None  LINESTRING (-76.66697 39.30002, -76.66587 39.3...
# 17               29  LINESTRING (-76.66535 39.30052, -76.66519 39.2...
# 18             None  LINESTRING (-76.67215 39.28185, -76.67214 39.2...
# 19  CityLink PURPLE  LINESTRING (-76.67263 39.28091, -76.66842 39.2...
# 20             None  LINESTRING (-76.62672 39.28670, -76.62668 39.2...
#
#                   mode  travel time (min)  wait time (min)
# 16  TransportMode.WALK               2.57             0.00
# 17   TransportMode.BUS               7.88             1.02
# 18  TransportMode.WALK               1.50             1.13
# 19   TransportMode.BUS              12.33             5.63
# 20  TransportMode.WALK              13.52             0.00

# %%
city_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f3e463e3612c50b2ba8d49e005a4ff99 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f3e463e3612c50b2ba8d49e005a4ff99&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f3e463e3612c50b2ba8d49e005a4ff99 = L.map(
#                 &quot;map_f3e463e3612c50b2ba8d49e005a4ff99&quot;,
#                 {
#                     center: [39.29, -76.648],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f2b3ecf3f90efba3d5ca0029847cf2c0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f3e463e3612c50b2ba8d49e005a4ff99);
#
#
#             var marker_5d97cf8b4b873a00d29a5c4602d90757 = L.marker(
#                 [39.30021456089469, -76.66651056263511],
#                 {}
#             ).addTo(map_f3e463e3612c50b2ba8d49e005a4ff99);
#
#
#             var icon_f24c22de2d8e2d2ae53a2cf6db7e5ec7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5d97cf8b4b873a00d29a5c4602d90757.setIcon(icon_f24c22de2d8e2d2ae53a2cf6db7e5ec7);
#
#
#             var marker_0f42918a492661010d57a710520332a8 = L.marker(
#                 [39.28641440580775, -76.62672154081966],
#                 {}
#             ).addTo(map_f3e463e3612c50b2ba8d49e005a4ff99);
#
#
#             var icon_47217f79deadc822b6aee65a311acebe = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0f42918a492661010d57a710520332a8.setIcon(icon_47217f79deadc822b6aee65a311acebe);
#
#
#             var poly_line_1d7d16bdc8da1294a377b7abd6c4e663 = L.polyline(
#                 [[39.3000169, -76.6669681], [39.3002162, -76.6658657], [39.3002844, -76.6653321], [39.3002871, -76.6652462], [39.3005255, -76.6652597], [39.300517, -76.66535]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f3e463e3612c50b2ba8d49e005a4ff99);
#
#
#             poly_line_1d7d16bdc8da1294a377b7abd6c4e663.bindTooltip(
#                 `&lt;div&gt;
#                      TransportMode.WALK
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_f0e9396189cadd7acad7dccddec82e19 = L.polyline(
#                 [[39.300517, -76.66535], [39.298251, -76.665193], [39.296671, -76.665128], [39.294483, -76.666411], [39.289873, -76.672593], [39.2889849, -76.672542], [39.286339, -76.672399], [39.283608, -76.67229], [39.281403, -76.672206]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f3e463e3612c50b2ba8d49e005a4ff99);
#
#
#             poly_line_f0e9396189cadd7acad7dccddec82e19.bindTooltip(
#                 `&lt;div&gt;
#                      TransportMode.BUS
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_942aa6b33bc2691819956b2d3d893d08 = L.polyline(
#                 [[39.2818491, -76.6721484], [39.2817757, -76.672143], [39.2816755, -76.6721383], [39.281404, -76.6721463], [39.281404, -76.6721463], [39.281222, -76.6721651], [39.2811049, -76.6721953], [39.280933, -76.6722496], [39.2809462, -76.6723403], [39.2809741, -76.6725331], [39.2809866, -76.6726194], [39.2810137, -76.6728064]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: &quot;5, 5&quot

# %%
options, travel_details, city_map = compute_itineraries(transport_network_after_newline, '245101607002002', '245100402001036')
print(options.min())
print(travel_details)
# Out:
# 34.9
#             from_id            to_id  option  segment      transport_mode  \
# 56  245101607002002  245100402001036      16        0  TransportMode.WALK
# 57  245101607002002  245100402001036      16        1  TransportMode.TRAM
# 58  245101607002002  245100402001036      16        2  TransportMode.WALK
#
#         departure_time  distance     travel_time       wait_time     route  \
# 56 2023-04-10 08:05:59   842.715 0 days 00:14:14 0 days 00:00:00      None
# 57 2023-04-10 08:23:36       NaN 0 days 00:08:19 0 days 00:01:07  Red Line
# 58 2023-04-10 08:32:55   666.844 0 days 00:11:14 0 days 00:00:00      None
#
#                                              geometry                mode  \
# 56  LINESTRING (-76.66697 39.30002, -76.66587 39.3...  TransportMode.WALK
# 57  LINESTRING (-76.66416 39.29445, -76.65333 39.2...  TransportMode.TRAM
# 58  LINESTRING (-76.62672 39.28670, -76.62668 39.2...  TransportMode.WALK
#
#     travel time (min)  wait time (min)
# 56              14.23             0.00
# 57               8.32             1.12
# 58              11.23             0.00

# %%
city_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f926aee23c8caced70b56c3bb60eb96b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f926aee23c8caced70b56c3bb60eb96b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f926aee23c8caced70b56c3bb60eb96b = L.map(
#                 &quot;map_f926aee23c8caced70b56c3bb60eb96b&quot;,
#                 {
#                     center: [39.29, -76.648],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5eb259e0fcdc0c98812e19b160796966 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f926aee23c8caced70b56c3bb60eb96b);
#
#
#             var marker_105ab202335a61525b3323c01a7efabc = L.marker(
#                 [39.30021456089469, -76.66651056263511],
#                 {}
#             ).addTo(map_f926aee23c8caced70b56c3bb60eb96b);
#
#
#             var icon_06b7ac3743f18504464abc1b5f30ead5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_105ab202335a61525b3323c01a7efabc.setIcon(icon_06b7ac3743f18504464abc1b5f30ead5);
#
#
#             var marker_9d47fbb9e7e045eb6dd58781ce0ec997 = L.marker(
#                 [39.28641440580775, -76.62672154081966],
#                 {}
#             ).addTo(map_f926aee23c8caced70b56c3bb60eb96b);
#
#
#             var icon_73e58dcb2e388c216e71f8181949cd6f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9d47fbb9e7e045eb6dd58781ce0ec997.setIcon(icon_73e58dcb2e388c216e71f8181949cd6f);
#
#
#             var poly_line_2e25a35a26a6e51194d66a49a05a66a8 = L.polyline(
#                 [[39.3000169, -76.6669681], [39.3002162, -76.6658657], [39.3002844, -76.6653321], [39.3002871, -76.6652462], [39.3000693, -76.6652338], [39.2992029, -76.6651845], [39.2990396, -76.6651752], [39.2986284, -76.6651518], [39.2982578, -76.6651284], [39.2980913, -76.6651179], [39.2980382, -76.6651146], [39.2979866, -76.6651119], [39.297606, -76.6650917], [39.2972102, -76.6650707], [39.297147, -76.6650674], [39.297081, -76.6650637], [39.2968073, -76.6650481], [39.2966854, -76.6650412], [39.2962346, -76.6650126], [39.2959642, -76.6649987], [39.2957126, -76.6649858], [39.2954506, -76.6649689], [39.2953627, -76.6649659], [39.2952285, -76.6649579], [39.2948361, -76.6649357], [39.2946724, -76.6649266], [39.2945345, -76.6649189], [39.2945362, -76.6648271], [39.2944044, -76.6648182], [39.2944195, -76.6644658], [39.2944325, -76.6641635], [39.2944461, -76.6641639]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f926aee23c8caced70b56c3bb60eb96b);
#
#
#             poly_line_2e25a35a26a6e51194d66a49a05a66a8.bindTooltip(
#                 `&lt;div&gt;
#                      TransportMode.WALK
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_53ddafcd01e8a2ce10f62af23b594034 = L.polyline(
#                 [[39.2944461, -76.6641639], [39.293159, -76.653328], [39.293568, -76.639083], [39.288974, -76.628931], [39.287554, -76.620219]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f926aee23c8caced70b56c3bb60eb96b);
#
#
#             poly_line_53ddafcd01e8a2ce10f62af23b594034.bindTooltip(
#                 `&lt;div&gt;
#                      TransportMode.TRAM
#                  &lt;/div&gt;`,

# %% [markdown]
# # Baron
# Baron travels from block 245102803011001 to 245100401002008

# %%
options, travel_details, city_map = compute_itineraries(transport_network_before_newline, '245102803011001', '245100401002008')
print(options.min())
print(travel_details)
# Out:
# 63.97
#              from_id            to_id  option  segment      transport_mode  \
# 179  245102803011001  245100401002008      33        0  TransportMode.WALK
# 180  245102803011001  245100401002008      33        1   TransportMode.BUS
# 181  245102803011001  245100401002008      33        2  TransportMode.WALK
# 182  245102803011001  245100401002008      33        3   TransportMode.BUS
# 183  245102803011001  245100401002008      33        4  TransportMode.WALK
# 184  245102803011001  245100401002008      33        5   TransportMode.BUS
# 185  245102803011001  245100401002008      33        6  TransportMode.WALK
#
#          departure_time  distance     travel_time       wait_time route  \
# 179 2023-04-10 08:00:06   260.946 0 days 00:04:22 0 days 00:00:00  None
# 180 2023-04-10 08:06:16       NaN 0 days 00:02:15 0 days 00:01:02    34
# 181 2023-04-10 08:09:31    83.286 0 days 00:01:21 0 days 00:01:14  None
# 182 2023-04-10 08:13:44       NaN 0 days 00:37:00 0 days 00:03:38    78
# 183 2023-04-10 08:51:44   462.344 0 days 00:07:48 0 days 00:00:56  None
# 184 2023-04-10 08:59:53       NaN 0 days 00:00:35 0 days 00:01:25    76
# 185 2023-04-10 09:01:28   139.932 0 days 00:02:23 0 days 00:00:00  None
#
#                                               geometry                mode  \
# 179  LINESTRING (-76.70718 39.30685, -76.70741 39.3...  TransportMode.WALK
# 180  LINESTRING (-76.70935 39.30734, -76.71093 39.3...   TransportMode.BUS
# 181  LINESTRING (-76.72501 39.29724, -76.72434 39.2...  TransportMode.WALK
# 182  LINESTRING (-76.72428 39.29762, -76.72278 39.2...   TransportMode.BUS
# 183  LINESTRING (-76.62269 39.28916, -76.62245 39.2...  TransportMode.WALK
# 184  LINESTRING (-76.62371 39.28611, -76.61956 39.2...   TransportMode.BUS
# 185  LINESTRING (-76.61926 39.28690, -76.61816 39.2...  TransportMode.WALK
#
#      travel time (min)  wait time (min)
# 179               4.37             0.00
# 180               2.25             1.03
# 181               1.35             1.23
# 182              37.00             3.63
# 183               7.80             0.93
# 184               0.58             1.42
# 185               2.38             0.00

# %%
city_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d43f8b8f14bc7d1c092215916f2f80c5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d43f8b8f14bc7d1c092215916f2f80c5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d43f8b8f14bc7d1c092215916f2f80c5 = L.map(
#                 &quot;map_d43f8b8f14bc7d1c092215916f2f80c5&quot;,
#                 {
#                     center: [39.29, -76.648],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aed46cdd30c9d00f6ab22734d2c7dc45 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d43f8b8f14bc7d1c092215916f2f80c5);
#
#
#             var marker_d575696c03c221f8ace47cbb464baaa0 = L.marker(
#                 [39.30700672208649, -76.7074602011923],
#                 {}
#             ).addTo(map_d43f8b8f14bc7d1c092215916f2f80c5);
#
#
#             var icon_ce0c9a8bd6624dfd71fb7dcefac54595 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d575696c03c221f8ace47cbb464baaa0.setIcon(icon_ce0c9a8bd6624dfd71fb7dcefac54595);
#
#
#             var marker_7fbedbf96f55fbf154f10e47acfb3121 = L.marker(
#                 [39.28698639905098, -76.61852752856659],
#                 {}
#             ).addTo(map_d43f8b8f14bc7d1c092215916f2f80c5);
#
#
#             var icon_7462a167156aeba9de669d3182a28d26 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7fbedbf96f55fbf154f10e47acfb3121.setIcon(icon_7462a167156aeba9de669d3182a28d26);
#
#
#             var poly_line_9927e7a593e4ee1f477edb7460d7fc85 = L.polyline(
#                 [[39.3068481, -76.707179], [39.3070061, -76.7074093], [39.306891, -76.7075408], [39.3067799, -76.7076682], [39.3066907, -76.7076038], [39.3064354, -76.7078948], [39.3064006, -76.7078419], [39.306353, -76.7078968], [39.3066289, -76.7083028], [39.3071849, -76.7091211], [39.3073085, -76.7093026], [39.3073369, -76.709348]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d43f8b8f14bc7d1c092215916f2f80c5);
#
#
#             poly_line_9927e7a593e4ee1f477edb7460d7fc85.bindTooltip(
#                 `&lt;div&gt;
#                      TransportMode.WALK
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_8ac0db08d93cbd89508e4f3497431769 = L.polyline(
#                 [[39.3073369, -76.709348], [39.305188, -76.7109289], [39.301453, -76.718884], [39.300531, -76.720528], [39.298478, -76.723405], [39.297279, -76.725027]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d43f8b8f14bc7d1c092215916f2f80c5);
#
#
#             poly_line_8ac0db08d93cbd89508e4f3497431769.bindTooltip(
#                 `&lt;div&gt;
#                      TransportMode.BUS
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_c663b1ac044d3e565d6c1ed5012ffa02 = L.polyline(
#                 [[39.2972388, -76.7250098], [39.2977185, -76.7243388], [39.2977903, -76.7244228], [39.2991514, -76.7260158]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;

# %%
options, travel_details, city_map = compute_itineraries(transport_network_after_newline, '245102803011001', '245100401002008')
print(options.min())
print(travel_details)
# Out:
# 43.28
#             from_id            to_id  option  segment      transport_mode  \
# 61  245102803011001  245100401002008      21        0  TransportMode.WALK
# 62  245102803011001  245100401002008      21        1   TransportMode.BUS
# 63  245102803011001  245100401002008      21        2  TransportMode.WALK
# 64  245102803011001  245100401002008      21        3  TransportMode.TRAM
# 65  245102803011001  245100401002008      21        4  TransportMode.WALK
#
#         departure_time  distance     travel_time       wait_time     route  \
# 61 2023-04-10 08:00:06   260.946 0 days 00:04:22 0 days 00:00:00      None
# 62 2023-04-10 08:06:16       NaN 0 days 00:01:24 0 days 00:01:02        34
# 63 2023-04-10 08:08:40   335.549 0 days 00:05:35 0 days 00:02:46      None
# 64 2023-04-10 08:20:35       NaN 0 days 00:19:20 0 days 00:05:34  Red Line
# 65 2023-04-10 08:48:55   191.730 0 days 00:03:14 0 days 00:00:00      None
#
#                                              geometry                mode  \
# 61  LINESTRING (-76.70718 39.30685, -76.70741 39.3...  TransportMode.WALK
# 62  LINESTRING (-76.70935 39.30734, -76.71093 39.3...   TransportMode.BUS
# 63  LINESTRING (-76.72050 39.30046, -76.71996 39.3...  TransportMode.WALK
# 64  LINESTRING (-76.71776 39.30283, -76.69178 39.2...  TransportMode.TRAM
# 65  LINESTRING (-76.61926 39.28690, -76.61816 39.2...  TransportMode.WALK
#
#     travel time (min)  wait time (min)
# 61               4.37             0.00
# 62               1.40             1.03
# 63               5.58             2.77
# 64              19.33             5.57
# 65               3.23             0.00

# %%
city_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8ccf65b75b96f1ed1e75d9173c817961 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8ccf65b75b96f1ed1e75d9173c817961&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8ccf65b75b96f1ed1e75d9173c817961 = L.map(
#                 &quot;map_8ccf65b75b96f1ed1e75d9173c817961&quot;,
#                 {
#                     center: [39.29, -76.648],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fca3044aecdef8703b73483563eb2642 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8ccf65b75b96f1ed1e75d9173c817961);
#
#
#             var marker_de99e792e11164f790e6c61e310cd8e8 = L.marker(
#                 [39.30700672208649, -76.7074602011923],
#                 {}
#             ).addTo(map_8ccf65b75b96f1ed1e75d9173c817961);
#
#
#             var icon_a040180d7a5417886b9f314813d87273 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_de99e792e11164f790e6c61e310cd8e8.setIcon(icon_a040180d7a5417886b9f314813d87273);
#
#
#             var marker_5c4cefb4297f9444a640589e8f0f6ecb = L.marker(
#                 [39.28698639905098, -76.61852752856659],
#                 {}
#             ).addTo(map_8ccf65b75b96f1ed1e75d9173c817961);
#
#
#             var icon_8f06fded5cadd273a1e68b97c2a2fe34 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5c4cefb4297f9444a640589e8f0f6ecb.setIcon(icon_8f06fded5cadd273a1e68b97c2a2fe34);
#
#
#             var poly_line_f80bfeac5d00df8e53663e5c5d0e7cb5 = L.polyline(
#                 [[39.3068481, -76.707179], [39.3070061, -76.7074093], [39.306891, -76.7075408], [39.3067799, -76.7076682], [39.3066907, -76.7076038], [39.3064354, -76.7078948], [39.3064006, -76.7078419], [39.306353, -76.7078968], [39.3066289, -76.7083028], [39.3071849, -76.7091211], [39.3073085, -76.7093026], [39.3073369, -76.709348]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8ccf65b75b96f1ed1e75d9173c817961);
#
#
#             poly_line_f80bfeac5d00df8e53663e5c5d0e7cb5.bindTooltip(
#                 `&lt;div&gt;
#                      TransportMode.WALK
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_bfb5c6ca37811264e14e720bc3c9f64b = L.polyline(
#                 [[39.3073369, -76.709348], [39.305188, -76.7109289], [39.301453, -76.718884], [39.300531, -76.720528]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8ccf65b75b96f1ed1e75d9173c817961);
#
#
#             poly_line_bfb5c6ca37811264e14e720bc3c9f64b.bindTooltip(
#                 `&lt;div&gt;
#                      TransportMode.BUS
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_3d6ca625d9eb6d13695047cc15ab7c3b = L.polyline(
#                 [[39.3004615, -76.7204987], [39.3008362, -76.7199647], [39.3010116, -76.7196965], [39.3010905, -76.7195398], [39.3011789, -76.7193486], [39.3013209, -76.7190058], [39.3013769, -76.7188657], [39.3014425, -76.7187021], [39.3014906, -76.7185821], [39.3016903, -76.7180362], [39.3019165, -76.7173843], [39.3019613, -76.7172551], [39.3019613, -76.7172551]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;

# %% [markdown]
# # Cory
# Cory travels from block 245102608001020 to 245100401002008

# %%
options, travel_details, city_map = compute_itineraries(transport_network_before_newline, '245102608001020', '245100401002008', center=[39.299236, -76.609383])
print(options.min())
print(travel_details)
# Out:
# 36.099999999999994
#             from_id            to_id  option  segment      transport_mode  \
# 31  245102608001020  245100401002008      11        0  TransportMode.WALK
# 32  245102608001020  245100401002008      11        1   TransportMode.BUS
# 33  245102608001020  245100401002008      11        2  TransportMode.WALK
#
#         departure_time  distance     travel_time       wait_time  \
# 31 2023-04-10 08:09:31   299.451 0 days 00:04:57 0 days 00:00:00
# 32 2023-04-10 08:08:02       NaN 0 days 00:20:45 0 days 00:01:03
# 33 2023-04-10 08:29:47   554.500 0 days 00:09:21 0 days 00:00:00
#
#               route                                           geometry  \
# 31             None  LINESTRING (-76.56310 39.28982, -76.56314 39.2...
# 32  CityLink ORANGE  LINESTRING (-76.56324 39.29163, -76.56548 39.2...
# 33             None  LINESTRING (-76.61926 39.28690, -76.61816 39.2...
#
#                   mode  travel time (min)  wait time (min)
# 31  TransportMode.WALK               4.95             0.00
# 32   TransportMode.BUS              20.75             1.05
# 33  TransportMode.WALK               9.35             0.00

# %%
city_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d8a2e67df5dd4222c8170383d5c79333 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d8a2e67df5dd4222c8170383d5c79333&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d8a2e67df5dd4222c8170383d5c79333 = L.map(
#                 &quot;map_d8a2e67df5dd4222c8170383d5c79333&quot;,
#                 {
#                     center: [39.299236, -76.609383],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fda79bb4c548f53170c724a42b195979 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d8a2e67df5dd4222c8170383d5c79333);
#
#
#             var marker_8a203b3f2264b74d6df58187f3e1271d = L.marker(
#                 [39.289628885392965, -76.56308925003322],
#                 {}
#             ).addTo(map_d8a2e67df5dd4222c8170383d5c79333);
#
#
#             var icon_30da46a7ccf99bd6368fe35beea593f3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8a203b3f2264b74d6df58187f3e1271d.setIcon(icon_30da46a7ccf99bd6368fe35beea593f3);
#
#
#             var marker_36fbbe0852af5033a9a547388fc23d69 = L.marker(
#                 [39.28698639905098, -76.61852752856659],
#                 {}
#             ).addTo(map_d8a2e67df5dd4222c8170383d5c79333);
#
#
#             var icon_c615d9525e4e97d7ddb0a429596762b7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_36fbbe0852af5033a9a547388fc23d69.setIcon(icon_c615d9525e4e97d7ddb0a429596762b7);
#
#
#             var poly_line_be337b4e7b359e959e1027bf98fdc76a = L.polyline(
#                 [[39.2898162, -76.5630999], [39.2904324, -76.563137], [39.2904164, -76.5636042], [39.2907117, -76.563622], [39.290995, -76.5636349], [39.2915588, -76.5636701], [39.2915756, -76.5632386], [39.291626, -76.5632399]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d8a2e67df5dd4222c8170383d5c79333);
#
#
#             poly_line_be337b4e7b359e959e1027bf98fdc76a.bindTooltip(
#                 `&lt;div&gt;
#                      TransportMode.WALK
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_5eaeddd836e00273a8252a1f2a169f59 = L.polyline(
#                 [[39.291626, -76.5632399], [39.29157, -76.565484], [39.292632, -76.569315], [39.294944, -76.569927], [39.294807, -76.573813], [39.294675, -76.576592], [39.294593, -76.579008], [39.294533, -76.581213], [39.294437, -76.583305], [39.294373, -76.5846959], [39.294289, -76.587376], [39.294213, -76.589144], [39.2941519, -76.5904149], [39.2940479, -76.594671], [39.293437, -76.596794], [39.292493, -76.600423], [39.292049, -76.601946], [39.291085, -76.605431], [39.290742, -76.6085109], [39.290658, -76.6099459], [39.290479, -76.612064], [39.290537, -76.613594], [39.290515, -76.616287], [39.290545, -76.619247], [39.290479, -76.620764]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d8a2e67df5dd4222c8170383d5c79333);
#
#
#             poly_line_5eaeddd836e00273a8252a1f2a169f59.bindTooltip(
#                 `&lt;div&gt;
#                      TransportMode.BUS
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_ec56d01139f7f8ad317096ea9f299457 = L.polyline(

# %%
options, travel_details, city_map = compute_itineraries(transport_network_after_newline, '245102608001020', '245100401002008', center=[39.299236, -76.609383])
print(options.min())
print(travel_details)
# Out:
# 29.36
#             from_id            to_id  option  segment      transport_mode  \
# 70  245102608001020  245100401002008      24        0  TransportMode.WALK
# 71  245102608001020  245100401002008      24        1  TransportMode.TRAM
# 72  245102608001020  245100401002008      24        2  TransportMode.WALK
#
#         departure_time  distance     travel_time       wait_time     route  \
# 70 2023-04-10 08:05:59   631.083 0 days 00:10:32 0 days 00:00:00      None
# 71 2023-04-10 08:16:09       NaN 0 days 00:14:31 0 days 00:01:05  Red Line
# 72 2023-04-10 08:39:40   191.730 0 days 00:03:14 0 days 00:00:00      None
#
#                                              geometry                mode  \
# 70  LINESTRING (-76.56310 39.28982, -76.56314 39.2...  TransportMode.WALK
# 71  LINESTRING (-76.56141 39.28716, -76.56587 39.2...  TransportMode.TRAM
# 72  LINESTRING (-76.61926 39.28690, -76.61816 39.2...  TransportMode.WALK
#
#     travel time (min)  wait time (min)
# 70              10.53             0.00
# 71              14.52             1.08
# 72               3.23             0.00

# %%
city_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4836dd5951c3dee22d0a9ed67544f972 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4836dd5951c3dee22d0a9ed67544f972&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4836dd5951c3dee22d0a9ed67544f972 = L.map(
#                 &quot;map_4836dd5951c3dee22d0a9ed67544f972&quot;,
#                 {
#                     center: [39.299236, -76.609383],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_534f79efd4a76b91f28f0557fb1c3cb1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4836dd5951c3dee22d0a9ed67544f972);
#
#
#             var marker_805fa6725a1317cdba1cc7b315cc2dd6 = L.marker(
#                 [39.289628885392965, -76.56308925003322],
#                 {}
#             ).addTo(map_4836dd5951c3dee22d0a9ed67544f972);
#
#
#             var icon_8b99c8ef56a48c11a2fa87353ef01e3e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_805fa6725a1317cdba1cc7b315cc2dd6.setIcon(icon_8b99c8ef56a48c11a2fa87353ef01e3e);
#
#
#             var marker_857d8c9b045850a39d6ab79c508560dc = L.marker(
#                 [39.28698639905098, -76.61852752856659],
#                 {}
#             ).addTo(map_4836dd5951c3dee22d0a9ed67544f972);
#
#
#             var icon_9819a176cb24393d504da68d7539ff5c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_857d8c9b045850a39d6ab79c508560dc.setIcon(icon_9819a176cb24393d504da68d7539ff5c);
#
#
#             var poly_line_529f53e75b5b17ac1d2cf35092c248e4 = L.polyline(
#                 [[39.2898162, -76.5630999], [39.2904324, -76.563137], [39.2904356, -76.5630621], [39.2904531, -76.5626579], [39.2888121, -76.5625485], [39.2883521, -76.5625186], [39.287826, -76.5624845], [39.2877482, -76.5624794], [39.2875184, -76.5624645], [39.2872845, -76.5624493], [39.2872474, -76.5624468], [39.2869783, -76.5624294], [39.2869024, -76.5624244], [39.286823, -76.5624193], [39.2868605, -76.5622725], [39.2869463, -76.562043], [39.2870285, -76.5618183], [39.2870873, -76.5616305], [39.2871269, -76.5614826], [39.2871393, -76.5614113], [39.287164, -76.561414]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4836dd5951c3dee22d0a9ed67544f972);
#
#
#             poly_line_529f53e75b5b17ac1d2cf35092c248e4.bindTooltip(
#                 `&lt;div&gt;
#                      TransportMode.WALK
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_be0eec6701b8a1b68cff3e511baf5837 = L.polyline(
#                 [[39.287164, -76.561414], [39.277368, -76.565872], [39.279397, -76.578288], [39.2845439, -76.5933699], [39.2843323, -76.5982197], [39.287811, -76.613653], [39.287554, -76.620219]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4836dd5951c3dee22d0a9ed67544f972);
#
#
#             poly_line_be0eec6701b8a1b68cff3e511baf5837.bindTooltip(
#                 `&lt;div&gt;
#                      TransportMode.TRAM
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_1a08c65d7a2a98370d902c11aa47602a = L.polyline(
#                 [[39.2869026, -76.6192633], [39.286961, -76.6181623], [39.2869026, -76.6192633], [39.2869

# %% [markdown]
# # Darrell
# Darrell travels from block 245102007015006 to 245102605013028

# %%
options, travel_details, city_map = compute_itineraries(transport_network_before_newline, '245102007015006', '245102605013028', center=[39.299236, -76.609383])
print(options.min())
print(travel_details)
# Out:
# 66.0
#              from_id            to_id  option  segment      transport_mode  \
# 109  245102007015006  245102605013028      26        0  TransportMode.WALK
# 110  245102007015006  245102605013028      26        1   TransportMode.BUS
# 111  245102007015006  245102605013028      26        2   TransportMode.BUS
# 112  245102007015006  245102605013028      26        3  TransportMode.WALK
#
#          departure_time  distance     travel_time       wait_time  \
# 109 2023-04-10 08:05:59   308.804 0 days 00:05:07 0 days 00:00:00
# 110 2023-04-10 08:13:53       NaN 0 days 00:28:55 0 days 00:01:02
# 111 2023-04-10 08:43:49       NaN 0 days 00:17:26 0 days 00:01:01
# 112 2023-04-10 09:02:15   759.217 0 days 00:12:29 0 days 00:00:00
#
#                route                                           geometry  \
# 109             None  LINESTRING (-76.67707 39.29302, -76.67705 39.2...
# 110    CityLink BLUE  LINESTRING (-76.67852 39.29381, -76.67587 39.2...
# 111  CityLink ORANGE  LINESTRING (-76.59345 39.29391, -76.59076 39.2...
# 112             None  LINESTRING (-76.54486 39.28544, -76.54608 39.2...
#
#                    mode  travel time (min)  wait time (min)
# 109  TransportMode.WALK               5.12             0.00
# 110   TransportMode.BUS              28.92             1.03
# 111   TransportMode.BUS              17.43             1.02
# 112  TransportMode.WALK              12.48             0.00

# %%
city_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7009b76e46421008277c975362035b2a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7009b76e46421008277c975362035b2a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7009b76e46421008277c975362035b2a = L.map(
#                 &quot;map_7009b76e46421008277c975362035b2a&quot;,
#                 {
#                     center: [39.299236, -76.609383],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cf176e789edddee33f06a998dc8a434c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7009b76e46421008277c975362035b2a);
#
#
#             var marker_d75286b746b75a0383982bfe609c1905 = L.marker(
#                 [39.293100346083094, -76.67712808140456],
#                 {}
#             ).addTo(map_7009b76e46421008277c975362035b2a);
#
#
#             var icon_f4d3427ab8b4e5450ee27326eba7add4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d75286b746b75a0383982bfe609c1905.setIcon(icon_f4d3427ab8b4e5450ee27326eba7add4);
#
#
#             var marker_496ea558a3c929a60878da1fa10db05a = L.marker(
#                 [39.28599416686469, -76.54498296061729],
#                 {}
#             ).addTo(map_7009b76e46421008277c975362035b2a);
#
#
#             var icon_fd10cdbcdb9e57f5dff7cc51fe45526e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_496ea558a3c929a60878da1fa10db05a.setIcon(icon_fd10cdbcdb9e57f5dff7cc51fe45526e);
#
#
#             var poly_line_81aed73e8bf0bc30868a4465794b8151 = L.polyline(
#                 [[39.2930208, -76.6770705], [39.2926658, -76.677046], [39.2926434, -76.6775855], [39.2926354, -76.6778436], [39.2926221, -76.6783064], [39.2934723, -76.6783528], [39.2938561, -76.6783739], [39.293808, -76.678517]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7009b76e46421008277c975362035b2a);
#
#
#             poly_line_81aed73e8bf0bc30868a4465794b8151.bindTooltip(
#                 `&lt;div&gt;
#                      TransportMode.WALK
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_ac05d260265172edfaebed254d3a2c26 = L.polyline(
#                 [[39.293808, -76.678517], [39.293906, -76.675865], [39.293998, -76.672858], [39.294177, -76.668077], [39.29406, -76.665429], [39.293057, -76.661779], [39.293317, -76.655647], [39.293025, -76.652256], [39.292705, -76.622656], [39.292761, -76.6214679], [39.292823, -76.619865], [39.292888, -76.618443], [39.292921, -76.616947], [39.292247, -76.61546], [39.2922889, -76.614255], [39.292087, -76.6112519], [39.289975, -76.605435], [39.290343, -76.603267], [39.290931, -76.6010639], [39.29242, -76.599495], [39.293041, -76.5974729], [39.293911, -76.593445]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7009b76e46421008277c975362035b2a);
#
#
#             poly_line_ac05d260265172edfaebed254d3a2c26.bindTooltip(
#                 `&lt;div&gt;
#                      TransportMode.BUS
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_5299c761c6edb12623dabfd0aa4518fd = L.polyline(
#                 [[39.293911, -76.593445], [39.294005, -76.590755], [39.294053,

# %%
options, travel_details, city_map = compute_itineraries(transport_network_after_newline, '245102007015006', '245102605013028', center=[39.299236, -76.609383])
print(options.min())
print(travel_details)
# Out:
# 54.8
#              from_id            to_id  option  segment      transport_mode  \
# 171  245102007015006  245102605013028      35        0  TransportMode.WALK
# 172  245102007015006  245102605013028      35        1  TransportMode.TRAM
# 173  245102007015006  245102605013028      35        2  TransportMode.WALK
# 174  245102007015006  245102605013028      35        3   TransportMode.BUS
# 175  245102007015006  245102605013028      35        4  TransportMode.WALK
#
#          departure_time  distance     travel_time       wait_time  \
# 171 2023-04-10 08:05:59   298.662 0 days 00:04:57 0 days 00:00:00
# 172 2023-04-10 08:13:19       NaN 0 days 00:27:32 0 days 00:01:02
# 173 2023-04-10 08:41:51   134.356 0 days 00:02:16 0 days 00:01:03
# 174 2023-04-10 08:44:59       NaN 0 days 00:03:40 0 days 00:01:49
# 175 2023-04-10 08:49:39   759.217 0 days 00:12:29 0 days 00:00:00
#
#                route                                           geometry  \
# 171             None  LINESTRING (-76.67707 39.29302, -76.67705 39.2...
# 172         Red Line  LINESTRING (-76.67841 39.29386, -76.66416 39.2...
# 173             None  LINESTRING (-76.55037 39.29110, -76.55034 39.2...
# 174  CityLink ORANGE  LINESTRING (-76.54979 39.28957, -76.54675 39.2...
# 175             None  LINESTRING (-76.54486 39.28544, -76.54608 39.2...
#
#                    mode  travel time (min)  wait time (min)
# 171  TransportMode.WALK               4.95             0.00
# 172  TransportMode.TRAM              27.53             1.03
# 173  TransportMode.WALK               2.27             1.05
# 174   TransportMode.BUS               3.67             1.82
# 175  TransportMode.WALK              12.48             0.00

# %%
city_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c5c111ab88cbefcdbce758cba27f160a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c5c111ab88cbefcdbce758cba27f160a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c5c111ab88cbefcdbce758cba27f160a = L.map(
#                 &quot;map_c5c111ab88cbefcdbce758cba27f160a&quot;,
#                 {
#                     center: [39.299236, -76.609383],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2b9029dd3fa67350f280fa336b6562e8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c5c111ab88cbefcdbce758cba27f160a);
#
#
#             var marker_c5f3d24a5c3c7fbfc73c8d4a874036e2 = L.marker(
#                 [39.293100346083094, -76.67712808140456],
#                 {}
#             ).addTo(map_c5c111ab88cbefcdbce758cba27f160a);
#
#
#             var icon_868a747ca184b3549d28f37dbb061733 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c5f3d24a5c3c7fbfc73c8d4a874036e2.setIcon(icon_868a747ca184b3549d28f37dbb061733);
#
#
#             var marker_26f1ec61e35ffa663b80e12e49cd3b2b = L.marker(
#                 [39.28599416686469, -76.54498296061729],
#                 {}
#             ).addTo(map_c5c111ab88cbefcdbce758cba27f160a);
#
#
#             var icon_259be3fa40db7c6b80749b341ff74e1f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_26f1ec61e35ffa663b80e12e49cd3b2b.setIcon(icon_259be3fa40db7c6b80749b341ff74e1f);
#
#
#             var poly_line_01a9d46e579004abb9c0fa880785ea9e = L.polyline(
#                 [[39.2930208, -76.6770705], [39.2926658, -76.677046], [39.2926434, -76.6775855], [39.2926354, -76.6778436], [39.2926221, -76.6783064], [39.2934723, -76.6783528], [39.2938561, -76.6783739], [39.293856, -76.678412]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c5c111ab88cbefcdbce758cba27f160a);
#
#
#             poly_line_01a9d46e579004abb9c0fa880785ea9e.bindTooltip(
#                 `&lt;div&gt;
#                      TransportMode.WALK
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_a243a00bb54ac837439c6b8d61852c35 = L.polyline(
#                 [[39.293856, -76.678412], [39.2944461, -76.6641639], [39.293159, -76.653328], [39.293568, -76.639083], [39.288974, -76.628931], [39.287554, -76.620219], [39.287811, -76.613653], [39.2843323, -76.5982197], [39.2845439, -76.5933699], [39.279397, -76.578288], [39.277368, -76.565872], [39.287164, -76.561414], [39.290448, -76.5503685]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c5c111ab88cbefcdbce758cba27f160a);
#
#
#             poly_line_a243a00bb54ac837439c6b8d61852c35.bindTooltip(
#                 `&lt;div&gt;
#                      TransportMode.TRAM
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_d13ac21ce7f0fbd10c5c8781940503a0 = L.polyline(
#                 [[39.291099, -76.5503735], [39.2904497, -76.5503446], [39.2903894, -76.550342], [39.2903891, -76.5501075], [39.290399, -76.5499399], [39.2900833, -76.5498693], [39.2899664, -76.5498403], [39.289826, -76.549819], [39.2897548, -76.5498008], [39.2896805, -76.549782], [39.2895955, -76.54
